# %%
import json
from kafka import KafkaConsumer

# %%
stations = {}
consumer = KafkaConsumer("velib-stations",  bootstrap_servers=['kafka:9093'], group_id="velib-monitor-stations")

# %%
for message in consumer:
    station = json.loads(message.value.decode())
    station_number = station["number"]
    contract = station["contract_name"]
    available_bike_stands = station["available_bike_stands"]

    if contract not in stations:
        stations[contract] = {}
    city_stations = stations[contract]
    if station_number not in city_stations:
        city_stations[station_number] = available_bike_stands

    count_diff = available_bike_stands - city_stations[station_number]
    if count_diff != 0:
        city_stations[station_number] = available_bike_stands
        print("{}{} {} ({})".format(
            "+" if count_diff > 0 else "",
            count_diff, station["address"], contract
        ))
# Out:
# -1 AVENIDA REINA MERCEDES - Aprox. Facultad de Informática (seville)
# -4 AVENIDA EDUARDO DATO - Aprox. C/ San Bernardo (seville)
# +1 LEOPOLD GOEBEL - ALLEE LEOPOLD GOEBEL ( DEVANT N° 109 ) (luxembourg)
# -1 K. ADENAUER - BOULEVARD KONRAD ADENAUER ( DEVANT BEI ) (luxembourg)
# +1 Portobello Road (dublin)
# -1 Pío XII - Campanar (valence)
# -1 PARC/PARK - RUE ROYALE  (FACE N°66-68)/KONINGSSTRAAT (TEGENOVER N°66-68) (bruxelles)
# -2 Partizanska cesta 46-48 (maribor)
# -1 Francia - Menorca (valence)
# -1 Strossmayerjeva ulica 3 (maribor)
# +1 AVENIDA RAMÓN Y CAJAL - Aprox. C/ Villegas Marmolejo (seville)
# -1 PRADO DE SAN SEBASTIAN - Estación de autobuses (seville)
# -1 Aragón - Ernesto Ferrer (valence)
# -1 Fenian Street (dublin)
# -1 Xátiva - Bailén (Estación del Norte) (valence)
# -1 South Dock Road (dublin)
# +1 The Point (dublin)
# +1 Jerónimo Monsoriu - Alcalde Cano Coloma (valence)
# +1 CALLE ANTIOQUIA - Aprox. Avda de Pedro Romero (seville)
# +1 PAUL JANSON - CHAUSSEE DE CHARLEROI/ CHARLEROISESTEENWEG 159 (bruxelles)
# -1 Slomškov trg 10 (maribor)
# -1 ALAMEDA DE HERCULES - Aprox. C/ Amor de Dios (seville)
# -2 Kilmainham Gaol (dublin)
# +1 Hardwicke Place (dublin)
# +2 Plaza San Felipe Neri (Mercado Algirós) (valence)
# -1 Talbot Street (dublin)
# +1 Colón, 60 (valence)
# -1 JOURDAN - RUE FROISSART (FACE 3 - 5) / FROISSARTSTRAAT (TEGENOVER 3 - 5) (bruxelles)
# -1 PARAISER PLAZ - Rue Sainte ZITHE devant n°49 angle Place de Paris (luxembourg)
# +1 Partizanska cesta 6a (maribor)
# -1 Naranjos (Magisterio) (valence)
# -1 Škrabčeva ulica 2 (ljubljana)
# -1 AVENIDA SAN FRANCISCO JAVIER - Aprox. C/ Camilo José Cela (seville)
# -1 AVENIDA DE ROMA - Puerta de Jerez (seville)
# -2 - KOLLEISCH - RUE DE BRAGANCE (luxembourg)
# +1 Jardines de Pereda (Aprox. Correos y Castelar) (santander)
# +1 WIELS - AV.WIELEMANS CEUPPENS/LAAN 7 (bruxelles)
# +1 Av. Puerto - Serrería (valence)
# +1 Cesta Ljubljanske brigade 33 (ljubljana)
# +1 Plaza América - Cirilo Amorós - Sorní (valence)
# +1 Portobello Harbour (dublin)
# +1 AVENIDA EDUARDO DATO - Aprox. Avda de San Francisco Javier (seville)
# -2 AUBERGE DE JEUNESSE - RUE DELAUNOY/STRAAT ,67 (bruxelles)
# -1 Beato Nicolás Factor - Convento de Jesús (valence)
# +1 Alfahuir - José Chabas Bordehore (valence)
# -1 Rue de l'industrie/Rue Chemin de Fer/ Rue de Strassen (luxembourg)
# -1 AVENIDA DIEGO MARTINEZ BARRIO - Aprox. Avda Gal Garcia de la Herranz (seville)
# +1 - GEMENG STROOSSEN - RUE DES ROMAINS (luxembourg)
# +1 Koroška cesta 173 (maribor)
# -1 Camp del Turia - Corts Valencianes (valence)
# +1 GARE DU MIDI / ZUIDSTATION - PLACE VICTOR HORTA / VICTOR HORTAPLEIN (bruxelles)
# -1 CALLE URQUIZA - Aprox. C/ Venecia (seville)
# +2 Princes Street / O'Connell Street (dublin)
# +1 SAINT-ADRIEN - AV DU PESAGE N°21 (bruxelles)
# +1 Jerónimo Monsoriu - Industria (valence)
# -1 CALLE DOCTOR JAIME MARCOS - Aprox. Avda. Doc. Fedriani (seville)
# +1 Av. Campanar (La Fe) (valence)
# -1 Ormond Quay Upper (dublin)
# -1 Poljanska cesta 20c (ljubljana)
# +1 SQUARE ANDRE - SQUARE EDOUARD ANDRE ( DEVANT N° 1 ) (luxembourg)
# -1 Leinster Street South (dublin)
# -2 STEPHANIE/STEFANIA - AV LOUISE/LOUIZALAAN 61A-63-65 (bruxelles)
# -1 Test Lyon au Labo Maurepas (lyon)
# -1  (lyon)
# -1 Place du Général de Gaulle devant la Gare - 95300 PONTOISE (cergy-pontoise)
# -1 ROSTAND PREFECTURE - 6 RUE EDMOND ROSTAND ANGLE RUE SYLVABELLE (marseille)
# +1 81 BVD DES Etats-Unis (lyon)
# +1 1 RUE DES TOURNEURS (toulouse)
# +1 33 Boulevard Yves Farge 69007 Lyon (lyon)
# +1 Rue de la Loire - place Gaston Defferre (nantes)
# +1 30 RUE GABRIEL PERI (toulouse)
# +1 Rue Colin - Angle rue Alexis Perroncel (lyon)
# +2 Rue Paul Bert (lyon)
# -1 Pierre Corneille/cours Franklin Roosevelt (lyon)
# -1 1 PL LANGE (toulouse)
# +1 8 ALL DES DEMOISELLES (toulouse)
# +1  (lyon)
# -1  (lyon)
# +6 2, allée Penthièvre (nantes)
# -1 PLACE DU BUSCA / FACE ECOLE JEAN JAURES (toulouse)
# +1 3B BD LASCROSSES (toulouse)
# +1 Rue du Professeur Beauvisage (lyon)
# +1 Rue de la Martinière (lyon)
# -1 44 BVD DES BROTTEAUX (lyon)
# +1 Parc des Glacis - Entrée Avenue de la Paix (besancon)
# +1 2 PL DE LA DAURADE (toulouse)
# +1 78 BD PIERRE ET MARIE CURIE (toulouse)
# +1 Angle bvd Anatole France (lyon)
# +1 Place Waldeck Rousseau - Pont Général de la Motte Rouge (nantes)
# -1 Rue Jacques Brel/angle rue Korel (lyon)
# -1 Angle rue Morellet (lyon)
# +1 Place Charles Hernu / côté sud (lyon)
# +5  (lyon)
# +1 Place Victor Basch (lyon)
# -2  (lyon)
# -1 95 AV. DE L'EUROPE (lyon)
# +1 2, place de la Duchesse Anne (nantes)
# -1 Au niveau de la rue Duvivier (lyon)
# -1 21 RUE LAFAYETTE (toulouse)
# -1 Angle rue Docteur Long/av. Lacassagne (lyon)
# -1 Angle République / rue de la Barre (lyon)
# -1 Place Foch (nantes)
# +1 5 PORT SAINT-SAUVEUR / ESPLANADE DE LA CAPITAINERIE (toulouse)
# -1 7 PLACE JULES GRANDCLEMENT (VILLEURBANNE) (lyon)
# +1 JULIEN 3 MAGES - COURS JULIEN ANGLE RUE DES TROIS MAGES (marseille)
# -1 Avenue Lacassagne (lyon)
# +1 Boulevard Mirabeau angle Rue Jean Gaspard Vence (marseille)
# +1 Face au 115 rue Pierre Baratin (lyon)
# +1 1, quai Moncousu - Pont Haudaudine (nantes)
# -1 Cours Emile Zola/Angle cours de la République (lyon)
# +1 33 RUE MONCEY (lyon)
# -1 57 BD DE L EMBOUCHURE (toulouse)
# +1 Devant le lycée (lyon)
# -1 Niveau rue de Sèze (lyon)
# -1 Quai de Malakoff - Canal Saint-Félix (nantes)
# -1 Rue Pasteur - Angle avenue Berthelot (lyon)
# +1 CATALANS CORNICHE - 69 CORNICHE J.F. KENNEDY ANGLE RUE DES CATALANS (marseille)
# +1 sur la place Croix Luizet (lyon)
# +1 49 COURS ARISTIDE BRIAND (CALUIRE) (lyon)
# +1 Face rue Massena, entrée centre commercial (lyon)
# +1  (lyon)
# +1 BD RICHARD WAGNER / ANGLE RUE ANTONIO VIVALDI (toulouse)
# -1 Avenue Albert Einstein au niveau du virage (lyon)
# +1 Angle avenue Berthelot (lyon)
# -1 27 boulevard Stalingrad (nantes)
# -2 Place Jean Macé - Face à la mairie (lyon)
# -1 86 RUE DE LA CHARITE (lyon)
# -1  (lyon)
# -1 Angle rue Nungesser et Coli (lyon)
# -1 61 RUE DU DAUPHINE (lyon)
# +1 Boulevard Stalingrad/angle rue Charlie Chaplin (lyon)
# +1 Angle Poulaillerie / République (lyon)
# -1 Angle rue Boileau (lyon)
# -1 69 BD LAZARE CARNOT (toulouse)
# +2 Face au cours Albert Thomas (lyon)
# +1 James Street East (dublin)
# -2 AVENIDA EDUARDO DATO - Aprox. C/ San Bernardo (seville)
# +1 Pearse Street (dublin)
# -1 LEOPOLD GOEBEL - ALLEE LEOPOLD GOEBEL ( DEVANT N° 109 ) (luxembourg)
# -1 Rue Albert Einstein/Bd de Kockelscheuer (luxembourg)
# -1 AVENIDA ALCALDE LUIS URUÑUELA - Aprox. Hotel Sevilla Congresos (seville)
# -1 Tehnološki park (ljubljana)
# -1 PLAZA NUEVA - Aprox. C/ Tetuan (seville)
# -1 Francia - Menorca (valence)
# +1 Pobreška cesta 18 (maribor)
# -2 Grudnovo nabrežje 3 (ljubljana)
# +1 Collins Barracks Museum (dublin)
# +1 Wilton Terrace (Park) (dublin)
# -1 Koroška cesta 74 (maribor)
# -1 Fenian Street (dublin)
# -1 Pavía - Columbretes (valence)
# +1 Gregorio Gea - Padre Ferris (valence)
# +1 AVENIDA REINA MERCEDES - Aprox. Escuela de arquitectura (seville)
# -1 Economista Gay - Luis Crumiere (valence)
# +1 Herbert Place (dublin)
# -1 Plaza San Felipe Neri (Mercado Algirós) (valence)
# +1 Pavía - Acequia de la Cadena (valence)
# +1 Alameda - Pintor Maella (valence)
# +1 CALLE LUIS MONTOTO - Aprox. C/ El Greco (seville)
# -1 AVENIDA DE LA CIUDAD JARDÍN - Aprox. C/ Profesor Braña (seville)
# +1 BOURSE / BEURS - RUE PAUL DEVAUX/PAUL DEVAUXSTRAAT (bruxelles)
# -2 PORTE DE NAMUR/NAAMSEPOORT - BOULEVARD DE WATERLOO 2 (bruxelles)
# +1 Germanías - Ruzafa (valence)
# -1 Partizanska cesta 6a (maribor)
# -1 Barcas, 11 (valence)
# +1 Blasco Ibañez, 23 (F. Filosofía y Psicología) (valence)
# +1 CARRETERA DE CARMONA - Aprox. C/ Maestro Solano (seville)
# +1 Pot rdečega križa (ljubljana)
# -1 General Elio - Llano del Real (valence)
# +1 Jardines de Pereda (Aprox. Correos y Castelar) (santander)
# -1 CALLE JOSÉ SARAMAGO - Aprox. Avda del Alcalde Juan Fernández (seville)
# -1 Trg OF 12 (ljubljana)
# -1 Trg MDB 9 (ljubljana)
# +1 AVENIDA REINA MERCEDES - Aprox. Glorieta Alcalde de Parias Merry (seville)
# -1 Prešernov trg 6 (ljubljana)
# +1 Dame Street (dublin)
# -1 C/Xàtiva 30-32 (valence)
# -1 Doctor Waksman - Nieves (valence)
# -2 Princes Street / O'Connell Street (dublin)
# -1 Miklošičeva cesta 20 (ljubljana)
# -1 Blasco Ibañez, 32 (F. Filología) (valence)
# +1 SQUARE ANDRE - SQUARE EDOUARD ANDRE ( DEVANT N° 1 ) (luxembourg)
# +1 ESTACIÓN RENFE SANTA JUSTA (seville)
# -1 Heuston Bridge (North) (dublin)
# -1 Ribera - Plaza Ayuntamiento (valence)
# -1 Plaza de los Fueros - Conde Trenor (valence)
# +1 VAN HELLEMONT - RUE DE NEERPEDE 372-374 / NEERPEDESTRAAT 372-374 (bruxelles)
# +1 新桜町７番 7 Shinsakura-machi (toyama)
# -1 富山市明輪町1内 Station Plaza South (toyama)
# +1 桜橋通り６番 6 Sakurabashi-dori (toyama)
# -1 50 QUAI ACHILLE LIGNON (lyon)
# +1 Angle montée de la Boucle (lyon)
# +1 ROME ITALIE BERLIOZ - FACE AU 10 RUE BERLIOZ (marseille)
# +1 139 AV. FELIX FAURE (lyon)
# -1 6 RUE BANCEL (lyon)
# -1 62 BD DE SUISSE (toulouse)
# +1 1 RUE DES TOURNEURS (toulouse)
# -1 Rue Colin - Angle rue Alexis Perroncel (lyon)
# +1 4 AV EDOUARD BELIN DEVANT ONERA FACE AU CREPS (toulouse)
# -1 Rue des petits prés  95000 CERGY (cergy-pontoise)
# -1 174–180 Avenue Jean Jaurès 69007 Lyon (lyon)
# -1 18 PL DU SALIN (toulouse)
# +1 1, boulevard des Martyrs Nantais de la Résistance (nantes)
# +1 12 PLACE LAGANNE (toulouse)
# -1 PLACE DU BUSCA / FACE ECOLE JEAN JAURES (toulouse)
# -1 FACE 100 AV YVES BRUNAUD (toulouse)
# -1 Face ancien Palais de Justice (lyon)
# +1 18 RUE BONNEFOY (toulouse)
# -1 Angle rue de la République (lyon)
# -1 16 RUE DES REMPARTS D'AINAY (lyon)
# +1 3 PLACE GAILLETON (lyon)
# +1  (lyon)
# +1 Devant le 8, place Mangin (nantes)
# +2 2 PL DE LA DAURADE (toulouse)
# +1 161/163 AV DE NEGRENEYS SUR ILOT CENTRAL (toulouse)
# +1  (lyon)
# +1 118 RUE MONCEY (lyon)
# +2 Devant l'entrée du parc (lyon)
# +1 74 RUE DE LA VILLETTE (lyon)
# -1 15, quai de Malakoff (nantes)
# +1 2 RUE CAPITAINE DESSEMOND (marseille)
# +1 Rue Docteur Dolard / Angle rue 4 Septembre (lyon)
# +1 Devant l'hôtel IBIS (lyon)
# -1  (lyon)
# +1 Devant entrée principale de l'université (lyon)
# -1 Place Victor Basch (lyon)
# -1 4, place Emile Sarradin (nantes)
# +1 CORNICHE LE PROPHETE - 327 CORNICHE J.F KENNEDY FACE A LA PLAGE DU PROPHETE EN DIRECTION DU VIEUX PORT (marseille)
# +1 Entre Herriot et République (lyon)
# -2 3 RUE JEAN DE TOURNES (lyon)
# +1 Rue de la République (lyon)
# +1 191 RTE D'ALBI (toulouse)
# -1 23, quai Ferdinand Favre (nantes)
# -1  (lyon)
# +2 52 AV. MARC SANGNIER (VILLEURBANNE) (lyon)
# +1 89B ALLEE CHARLES DE FITTE (toulouse)
# -1 54 BVD PINEL (lyon)
# +2 PLACE SEBASTOPOL - 20 PLACE SEBASTOPOL (marseille)
# -1 Rue de la SINNE angle rue CH.BRUN devant Eglise St ETIENNE (mulhouse)
# +1 30, boulevard Gabriel Guist'Hau - Rue Harouys (nantes)
# +1 2 PLACE SAINT-PIERRE (toulouse)
# -1 Angle rue Garibaldi (lyon)
# -5 Cours Emile Zola/Angle cours de la République (lyon)
# -2 A côté du stand de fleurs (lyon)
# -1 Angle Cours Vitton (lyon)
# +1 61 RUE DE LA CONCORDE (toulouse)
# +1 Sur le quai devant l'entrée de la piscine (lyon)
# -1 RUE DU 8 MAI 1945 / FACE JARDIN ROYAL (toulouse)
# -3 66 RUE PARGAMINIERES (toulouse)
# -1 Avenue Albert Einstein au niveau du virage (lyon)
# -1  (lyon)
# -1 RUE JULES VERNE / ANGLE FACE 40 BD SILVIO TRENTIN (toulouse)
# -1 7 BD DE STRASBOURG (toulouse)
# -1 1 PL DES CARMES (toulouse)
# -1 Angle Poulaillerie / République (lyon)
# +1 3, rue Pierre Chereau (nantes)
# +1 103 RUE PIERRE VOYANT (VILLEURBANNE) (lyon)
# -1 69 BD LAZARE CARNOT (toulouse)
# -1 Fontanars dels Aforins - Vall d'Uixó (valence)
# -1 Vilharjeva cesta 23 (ljubljana)
# -1 AVENIDA ALEMANIA - Aprox. Glorieta Chekia (seville)
# +1 LEOPOLD GOEBEL - ALLEE LEOPOLD GOEBEL ( DEVANT N° 109 ) (luxembourg)
# +1 Cankarjeva cesta 1 (ljubljana)
# -1 Francisco Cubells - San José de la Vega (valence)
# -1 PLAZA NUEVA - Aprox. C/ Tetuan (seville)
# -2 Frederick Street South (dublin)
# -1 LEYDENBACH - RUE LEYDENBACH / RUE DES LABOURS (luxembourg)
# -1 Pobreška cesta 18 (maribor)
# -1 Ricardo Muñoz Suay - María José Victoria Fuster (C.C. El Saler) (valence)
# -1 PLAZA DUQUESA DE ALBA - Puente de la Barqueta (seville)
# -1 Pio XII - Menéndez PIdal (Nuevo Centro) (valence)
# +1 PLAZA DEL MUSEO - Aprox. C/ Alfonso XII (seville)
# +1 Hanover Quay (dublin)
# -1 Collins Barracks Museum (dublin)
# -1 Slovenska cesta 55c (ljubljana)
# -1 PHILHARMONIE - AVENUE JF KENNEDY / PLACE DE L'EUROPE (luxembourg)
# +1 Koroška cesta 74 (maribor)
# -1 Gunduličeva ulica (ljubljana)
# -1 South Dock Road (dublin)
# +1 Ciudad de Ronda - Aprox. Avda Carlos V (seville)
# +1 Plaza San Felipe Neri (Mercado Algirós) (valence)
# -1 DEMEY - INTERSECTION BD INVALIDENLAAN / AV LOUIS DEHOUXLAAN (bruxelles)
# +2 ROUSEGAERTCHEN - PLACE DES MARTYRS (luxembourg)
# +1 Kongresni trg 3 (ljubljana)
# -1 Kevin Street (dublin)
# -1 Gerbičeva ulica 61 (ljubljana)
# -1 Grand Canal Dock (dublin)
# +1 BOURSE / BEURS - RUE PAUL DEVAUX/PAUL DEVAUXSTRAAT (bruxelles)
# +1 Denmark Street Great (dublin)
# -1 CALLE FERIA - Aprox. C/ Resolana (seville)
# -1 Razlagova ulica 1 (maribor)
# +5 Partizanska cesta 6a (maribor)
# -2 Plaza de la Virgen - Bailía (valence)
# +1 - KOLLEISCH - RUE DE BRAGANCE (luxembourg)
# +1 MIDI FONSNY/ZUID FONSNY - RUE D'ANGLETERRE / ENGELANDSTRAAT (bruxelles)
# -1 AVENIDA KANSAS CITY - Aprox. Hotel Occidental (seville)
# -1 Blasco Ibañez - Poeta Durán Tortajada (valence)
# -1 DANSAERT - RUE ANTOINE DANSAERT/ANTOINE DANSAERTSTRAAT 60-62-64 (bruxelles)
# -1 Merrion Square West (dublin)
# -1 Doctor Nicasio Benlloch - L'Horta Sud (valence)
# +1 CALLE MANUEL SIUROT - Aprox. Hospital Universitario Virgen del Rocio (seville)
# +1 CALLE REYES CATÓLICOS - Aprox. C/ Gravina (seville)
# +2 Princes Street / O'Connell Street (dublin)
# +1 SQUARE ANDRE - SQUARE EDOUARD ANDRE ( DEVANT N° 1 ) (luxembourg)
# -1 Av. Puerto - Plaza Tribunal de les Aigües (valence)
# +1 Regne de Valencia - Almirante Cadarso (valence)
# +1 Corts Valencianes - La Safor (valence)
# -1 VAN HELLEMONT - RUE DE NEERPEDE 372-374 / NEERPEDESTRAAT 372-374 (bruxelles)
# -2 50 QUAI ACHILLE LIGNON (lyon)
# +1 68 BD JEAN BRUNHES FACE AU 53 (toulouse)
# -1 1 RUE DES TOURNEURS (toulouse)
# -1 69 RUE AUDIBERT ET LAVIROTTE (lyon)
# +1 55 RUE DE LA VILLETTE (lyon)
# +1 12 RUE DU POIDS DE L'HUILE (toulouse)
# -1 BAILLE FRIEDLAND - BOULEVARD BAILLE ANGLE RUE DE FRIEDLAND (marseille)
# +1 Rue Florian/Angle Cours Tolstoï (lyon)
# +1 Rue de la Gare - REZÉ (nantes)
# -1  (lyon)
# -1 64 AV. MARCEL CERDAN (lyon)
# -1 18 RUE BONNEFOY (toulouse)
# -1  (lyon)
# -1 14 PL SAINT-ETIENNE (toulouse)
# -1 3 PLACE GAILLETON (lyon)
# -1 RUE LEONCE DUCLOS / ANGLE AV DE FRONTON FACE 26 IMP DU BARON (toulouse)
# +1 Rue Roger Salengro - Angle rue Vaillant (lyon)
# +1 1 AV PAUL SEJOURNE (toulouse)
# +1  (lyon)
# +1 Devant l'entrée du parc (lyon)
# -1  (lyon)
# -1 45 RUE DE LA POUDRETTE (VILLEURBANNE) (lyon)
# +1 74 RUE DE LA VILLETTE (lyon)
# -1 Place Charles Hernu / côté sud (lyon)
# +1 2 RUE CAPITAINE DESSEMOND (marseille)
# -1 14 bis, rue Lamoricière - Place Beaumanoir (nantes)
# +1 Angle rue Vendôme (lyon)
# -1 1 RUE DES 7 TROUBADOURS (toulouse)
# +1 2 BD DEODAT DE SEVERAC (toulouse)
# -1 Place Leclerc (besancon)
# -1 Place Meissonier - Angle Sud-Est de la place (lyon)
# -1 10 PLACE SAINTE ANNE (lyon)
# -1 84 avenue des Arts (lyon)
# +1 Place du Port Communeau (nantes)
# -1 3 RUE JEAN DE TOURNES (lyon)
# -1 Allée A. Lignon (lyon)
# -1 Intersection Ferrandière/Jasseron (lyon)
# -1 4 PLACE RASPAIL (lyon)
# +1 52 AV. MARC SANGNIER (VILLEURBANNE) (lyon)
# +1 7 PLACE JULES GRANDCLEMENT (VILLEURBANNE) (lyon)
# -1 PLACE SEBASTOPOL - 20 PLACE SEBASTOPOL (marseille)
# +1 Rue Anatole France (lyon)
# -1 4 RUE DE LA CONCORDE (toulouse)
# +1 17 PLACE JULES FERRY (lyon)
# +1 Angle rue Servient (lyon)
# -1 Place Jules Ferry angle rue Général Brosset face à la gare des Brotteaux (lyon)
# -1 2 PLACE SAINT-PIERRE (toulouse)
# -2 26 AV LEON BLUM ANGLE RUE LEON JOUHAUX (toulouse)
# -4 Cours Emile Zola/Angle cours de la République (lyon)
# -1  (lyon)
# -1 RUE LEON JOUHAUX MULHOUSE (mulhouse)
# -1 FACE 58 RUE DUMERIL (toulouse)
# -1 43 BVD DU 11 NOVEMBRE 1918 (VILLEURBANNE) (lyon)
# -1 50 GRANDE RUE SAINT-MICHEL (toulouse)
# +1 Angle rue Serlin - Angle place de la comédie (lyon)
# -1 4 BD DE STRASBOURG (toulouse)
# -1 14 PL DOMINIQUE MARTIN DUPUY (toulouse)
# +1 Rue de la Madeleine - Angle rue St Lazarre (lyon)
# +1 139 GRANDE RUE SAINT-MICHEL (toulouse)
# -1 Place Jean Macé - Face à la mairie (lyon)
# -1 55 QUAI PIERRE SCIZE (lyon)
# -2  (lyon)
# +1 54 RUE DES SEPT TROUBADOURS (toulouse)
# +1 Avenue Debourg - Angle avenue Jean Jaurès (lyon)
# -1 Angle rue Boileau (lyon)
# -1 Face au cours Albert Thomas (lyon)
# +1 Devant le n°63 rue de Trion (lyon)
# +1 Angle rue Paul Bert (lyon)
# +1 CALLE BETIS - Aprox. C/ Juan de Lugo (seville)
# -1 Justo y Pastor - Duque de Gaeta (valence)
# +1 Glavni trg 20 (maribor)
# -1 LEOPOLD GOEBEL - ALLEE LEOPOLD GOEBEL ( DEVANT N° 109 ) (luxembourg)
# +1 PLAZA CHAPINA - Aprox. Hotel Abba Triana (seville)
# -1 Navarro Reverter - Grabador Esteve (valence)
# +1 Guillem de Castro (Torres de Quart) (valence)
# -1 Partizanska cesta 46-48 (maribor)
# +1 Pobreška cesta 18 (maribor)
# -1 CALLE TESALÓNICA - Calle Mazzantini (seville)
# -1 Aragón - Ernesto Ferrer (valence)
# +2 Juan Verdeguer - Toneleros (valence)
# -1 CALLE ROMA - Aprox. C/ Palos de la Frontera (seville)
# -1 Reig Genovés - Ramón Contreras Mongrell (valence)
# +1 Blasco Ibañez - Clariano (valence)
# +1 TERDELT - PLACE TERDELT / TERDELTPLEIN (bruxelles)
# -1 Dunajska cesta 105 (ljubljana)
# -1 Pavía - Columbretes (valence)
# -1 - MERKELS PLAZ - RUE JEAN BAPTISTE MERKELS / Bd CHARLES MARX (luxembourg)
# -1 SCHUMAN - RUE DE LA LOI 170 (bruxelles)
# +1 PLAZA NUEVA - Aprox. C/ Mendez Núñez (seville)
# +2 Blasco Ibañez - Yecla (valence)
# +1 Hatch Street (dublin)
# +1 Wolfe Tone Street (dublin)
# -1 Herbert Place (dublin)
# +1 Dunajska cesta 50 (ljubljana)
# -1 PLACE VAN MEYEL/VAN MEYELPLEIN (bruxelles)
# +1 Pintor Luis Arcas - Inst. Obrero Valenciano (valence)
# +1 ROUSEGAERTCHEN - PLACE DES MARTYRS (luxembourg)
# +2 Killarney Street (dublin)
# +1 Av. Puerto - José Aguilar (valence)
# -1 Alameda - Pintor Maella (valence)
# -1 AVENIDA LA BUHAIRA - Aprox. Avda Luis Montoto (seville)
# +1 Hermanos Maristas - General Urrutia (valence)
# +1 MONTEREY - AVENUE DE MONTEREY ( FACE N° 49 ) (luxembourg)
# +1 PORTE DE NAMUR/NAAMSEPOORT - BOULEVARD DE WATERLOO 2 (bruxelles)
# +2 Škrabčeva ulica 2 (ljubljana)
# -1 Celovška cesta 111c (ljubljana)
# +1 PLAZA DEL ZURRAQUE - Aprox. C/ Doc. Jeronimo Pou (seville)
# -1 MONTGOMERY - AVENUE DE TERVUREN / TERVURENLAAN 136-138 (bruxelles)
# -1 MÄRELER PARC - RUE DU 10 SEPTEMBRE ( DEVANT N° 108 ) (luxembourg)
# +1 PARLAMENTO - Aprox. C/ Don Fadrique (seville)
# -1 Amadeo de Saboya (frente Ayuntamiento) (valence)
# -1 Hospital - Horno del Hospital (valence)
# -1 AVENIDA DE MIRAFLORES - Aprox. C/ Albaida (seville)
# -1 Portobello Harbour (dublin)
# -1 MIDI FONSNY/ZUID FONSNY - RUE D'ANGLETERRE / ENGELANDSTRAAT (bruxelles)
# -1 AVENIDA EDUARDO DATO - Aprox. Avda de San Francisco Javier (seville)
# -1 PLAZA SAN FRANCISCO - Aprox C/ Hernando Colón (seville)
# -1 RONDA URBANA NORTE - Aprox. C/ Doctor Fedriani (seville)
# -2 Doctor Lluch - Virgen del Sufragio (valence)
# +3 CAMPUS LAMPERTSBIERG - RUE DE LA FAIENCERIE ( DEVANT N° 151 ) (luxembourg)
# -1 Manuel Candela - Rodriguez de Cepeda (valence)
# -1 Dame Street (dublin)
# +1 CALLE DE HERNÁN CORTÉS - Aprox. C/ Eslava (seville)
# -1 Doctor Waksman - Nieves (valence)
# +1 Breg 20 (ljubljana)
# +1 GARE CENTRALE/CENTRAAL STATION - BLD DE L'IMPERATRICE/KEIZERINLAAN (bruxelles)
# +1 DE BROUCKERE - PLACE DE BROUCKERE/DE BROUCKEREPLEIN (bruxelles)
# +1 Poljanska cesta 20c (ljubljana)
# +1 FORT NIEDERGRÜNEWALD - RUE DU FORT NIEDERGRÜNEWALD/KENNEDY (luxembourg)
# -1 Nove Fuzine 33 (ljubljana)
# -1 Dunajska cesta 70 (ljubljana)
# +1 牛島本町2丁目1-38　2-1-38 Ushijimahonncho (toyama)
# -1 富山市明輪町1内 Station Plaza South (toyama)
# -1 AVENUE DU SUD - 95000 CERGY (cergy-pontoise)
# +1 16 BVD DE LA CROIX-ROUSSE (lyon)
# -1 76 AV. LACASSAGNE (lyon)
# +1 12 RUE SANTOS DUMONT (lyon)
# +1 32 PL ROQUELAINE (toulouse)
# +1 33 AV HONORE SERRES (toulouse)
# -1  (lyon)
# -1 12 RUE DU POIDS DE L'HUILE (toulouse)
# +1 55 RUE DE BARABAN (lyon)
# +1 Angle Bvd de la Croix-Rousse (lyon)
# -1 Angle rue Anselme, face à l'IUFM (lyon)
# -1 1 BIS ALLEE JULES GUESDE (toulouse)
# -1 Face ancien Palais de Justice (lyon)
# -1 RUE DES CHÊNES D'OR ANGLE BOULEVARD DU PORT - 95000 CERGY (cergy-pontoise)
# +1  (lyon)
# +1 Angle rue de la Madeleine (lyon)
# +1 Côté route de Vienne (lyon)
# +1 5 PLACE DU FER A CHEVAL (toulouse)
# +1 Angle rue Morellet (lyon)
# +1 RUE ROQUEMAUREL / ANGLE 3 RUE ANNE FRANCK (toulouse)
# -1 PROMENADE POMPIDOU DAVID -  PROMENADE GEORGES POMPIDOU AU NIVEAU DU ROND POINT DE DAVID (marseille)
# +1 39 BD ARMAND DUPORTAL (toulouse)
# +1 84 avenue des Arts (lyon)
# +2 15, rue de Verdun (nantes)
# -1 21 RUE LAFAYETTE (toulouse)
# -1 Angle cours Gambetta (lyon)
# -1 12 QUAI ST AINTOINE (lyon)
# +1 15 PL ETIENNE ESQUIROL (toulouse)
# -1 184 ROUTE DE VIENNE (lyon)
# -1 Angle rue Villon (lyon)
# -1 7 RUE DES SALENQUES (toulouse)
# +1 32 BD DE STRASBOURG (toulouse)
# -1 4 PLACE RASPAIL (lyon)
# +1 7 PLACE JULES GRANDCLEMENT (VILLEURBANNE) (lyon)
# +1 10 QUAI PAUL SEDAILLAN (lyon)
# +1 65 RUE MAZENOD (lyon)
# +1 1, allée de l'Île Gloriette (nantes)
# +1 1 RUE DU GENERAL COMPANS (toulouse)
# -1 PLACE DU VIEUX MARCHE (rouen)
# +1 Rue Pierre Louis Athénas (nantes)
# -4 26 AV LEON BLUM ANGLE RUE LEON JOUHAUX (toulouse)
# +1 Cours Emile Zola/Angle cours de la République (lyon)
# +1  (lyon)
# +1 Angle rue Serlin - Angle place de la comédie (lyon)
# +1 49 COURS ARISTIDE BRIAND (CALUIRE) (lyon)
# -1 Face rue Massena, entrée centre commercial (lyon)
# -1 66 TER AV ETIENNE BILLIERES (toulouse)
# +1 Rue Herriot - Devant Musée des Beaux Arts (lyon)
# -1 27 boulevard Stalingrad (nantes)
# +1 Avenue Debourg - Angle avenue Jean Jaurès (lyon)
# +1 26 RUE DE PERIGORD (toulouse)
# -2 101 cours Charlemagne Lyon 2 direction centre ville. Devant l'hôtel de Région (lyon)
# +1 69 BD LAZARE CARNOT (toulouse)
# +1 Fontanars dels Aforins - Vall d'Uixó (valence)
# -1 CALLE LUIS MONTOTO - Aprox. C/ Maese Farfán (seville)
# -1 Christchurch Place (dublin)
# +1 AL BRÉCK - VIADUC / BOULEVARD DE LA PETRUSSE (luxembourg)
# -1 Prušnikova ulica (ljubljana)
# +1 PLAZA NUEVA - Aprox. C/ Tetuan (seville)
# +1 Manuel Broseta i Pont - Naranjos (valence)
# +1 San Vicente Paul - Santiago Rusiñol (valence)
# -1 Grudnovo nabrežje 3 (ljubljana)
# -1 CALLE ARROYO - Aprox. Avda. José Laguillo (seville)
# -1 Ramón Llull - Serpis (valence)
# -1 TERDELT - PLACE TERDELT / TERDELTPLEIN (bruxelles)
# +1 Dunajska cesta 105 (ljubljana)
# +1 BASCULE -  CHAUSSEE DE VLEURGAT (DEVANT 315 - 317) / VLEURGATSESTEENWEG  (N° 315 - 317) (bruxelles)
# -1 PLAZA DE ARMAS - Avda Torneo (estación de autobuses) (seville)
# -1 UPV Informática (valence)
# -1 Av. del Cid - Marconi (valence)
# -1 Reina Violante - Escultor García Mas (valence)
# -1 Zoisova cesta 2 (ljubljana)
# +1 AVENIDA DE LA CIUDAD JARDÍN - Aprox. C/ Profesor Braña (seville)
# +1 Hermanos Maristas - General Urrutia (valence)
# +1 Grand Canal Dock (dublin)
# -1 York Street West (dublin)
# -1 Denmark Street Great (dublin)
# +1 Blasco Ibañez - Jaime Roig (valence)
# +1 CALLE RAMÓN CARANDE - Aprox. C/ San Salvador (seville)
# +1 PLACE DE FRANCE - PLACE DE FRANCE (luxembourg)
# +1 Aragón - Vicente Sancho Tello (valence)
# +1 Jorge Comin (Metge) - Terrateig (valence)
# -1 La Safor - Maestro Rodrigo (valence)
# +1 Maestro Rodrigo - Manuel de Falla (valence)
# -1 Alameda - Pintor Monleón (valence)
# +1 DANSAERT - RUE ANTOINE DANSAERT/ANTOINE DANSAERTSTRAAT 60-62-64 (bruxelles)
# -1 GLORIETA DEL PRIMERO DE MAYO - Aprox. C/ Carlos Marx (seville)
# +1 Hospital Nueva Fe (consultas externas) (valence)
# -1 Convention Centre (dublin)
# +1 RONDA URBANA NORTE - Aprox. C/ Doctor Fedriani (seville)
# +1 Trg MDB 9 (ljubljana)
# +1 Peris y Valero - Luis Santángel (valence)
# +1 CAMPUS LAMPERTSBIERG - RUE DE LA FAIENCERIE ( DEVANT N° 151 ) (luxembourg)
# +1 Guillem de Castro - San Pedro Pascual (valence)
# +1 ALAMEDA DE HERCULES - Aprox. Calle Peris Mencheta (seville)
# -1 Miklošičeva cesta 20 (ljubljana)
# +1 Devinska ulica 1a (ljubljana)
# +1 Poljanska cesta 20c (ljubljana)
# +1 Emmet Road (dublin)
# +2 JARDIN AUX FLEURS/BLOEMENHOF - PLACE DU JARDIN AUX FLEURS/BLOEMENHOFPLEIN - RUE DES 6 JETONS/ZES PENNIGENSTRAAT 71 (bruxelles)
# -1 AVENIDA CARDENAL BUENO MONREAL - Aprox. Avda Manuel Siurot (seville)
# +1 50 QUAI ACHILLE LIGNON (lyon)
# +1 SAINT CHARLES MARSEILLAISES - PLACE DES MARSEILLAISES ANGLE RUE PHILIPPE DE GIRARD (marseille)
# +1 139 AV. FELIX FAURE (lyon)
# +1 81 BVD DES Etats-Unis (lyon)
# -1 Cours Gambette - Prolongement rue Rachais (lyon)
# +1 Rue de la Loire - place Gaston Defferre (nantes)
# -1 Allée de la Bourse - Boulevard des Nations-Unies (nantes)
# -1 62 RUE DE LA POMME (toulouse)
# -1 A côté de l'église (lyon)
# +1 Rue Paul Bert (lyon)
# +1  (lyon)
# -1 3B BD LASCROSSES (toulouse)
# -1 12 AV BOURGES MAUNOURY (toulouse)
# -1 Face ancien Palais de Justice (lyon)
# -1 25, boulevard de la Prairie au Duc (nantes)
# +1 Rue Gutenberg angle rue l'Arsenal (mulhouse)
# +2 Entre rue Crillon et rue Sully (lyon)
# -1  (lyon)
# -1 1 AV PAUL SEJOURNE (toulouse)
# +1 153 RUE CREQUI (lyon)
# +1 Angle rue de la Part-Dieu (lyon)
# -1 PROMENADE POMPIDOU AMIRAL MUSELIER - PROMENADE GEORGES POMPIDOU DEVANT LA PLACE AMIRAL MUSELIER (marseille)
# -1 Angle rue Vendôme (lyon)
# -1 AVENUE FELIX FAURE ANGLE VIVIER MERLE. 10M AVANT VIVIER MERLE EN DIRECTION DU RHONE (lyon)
# +1 57 AV DE L'URSS (toulouse)
# -1 170 Boulevard des Etats-Unis, Angle Avenue Viviani, direction Venissieux (lyon)
# +1 Côté rue des Marroniers (lyon)
# -1  (lyon)
# -1 10 PLACE SAINTE ANNE (lyon)
# -1 Devant entrée principale de l'université (lyon)
# +1 PRADO GABES - AVENUE DU PRADO ANGLE BD DE GABES (marseille)
# +1 274 COURS EMILE ZOLA (VILLEURBANNE) (lyon)
# +1 Avenue Louise Michel angle rue Plançon (besancon)
# -1 Angle cours Gambetta (lyon)
# -1 Entre Herriot et République (lyon)
# -1 7 AV EDOUARD BELIN ANGLE AV ROCHE RD-PT GUY DU MERLE (toulouse)
# +1 Place Victor Hugo (au niveau de la porte Noire, entrée de la Citadelle) (besancon)
# +1 87 AV JEAN BAYLET / ANGLE CHEMIN CEPIERES SUR PARKING LYCEE POLYVALENT (toulouse)
# +1 Face à la faculté catholique (lyon)
# +1 Angle rue d'Algérie (lyon)
# +1 256 AV ANTOINE DE ST EXUPERY (toulouse)
# -1 Intersection Rockefeller / Esquirol (lyon)
# -1 43 RUE PIERRE BARATIN (VILLEURBANNE) (lyon)
# -1 4 RUE DE LA CONCORDE (toulouse)
# -1 PARADIS LORD DUVEEN - 395 RUE PARADIS (marseille)
# -1 Entre la cathédrale et le funiculaire (lyon)
# -1 PLACE EMILE MALE (toulouse)
# -1  (lyon)
# +2 2 PLACE SAINT-PIERRE (toulouse)
# -1  (lyon)
# +1 Rue de Belfort angle rue Suard (besancon)
# +1 Angle Gambetta (lyon)
# +1 30 RUE ROUBICHOU (toulouse)
# -1 LANCIER MARTHELINE - ANGLE CHEMIN DU LANCIER ET AVENUE DE LA  MARTHELINE (marseille)
# -1 Angle Cours Vitton (lyon)
# -1  (lyon)
# +1 Sur le quai devant l'entrée de la piscine (lyon)
# +1 Rue Pasteur - Angle avenue Berthelot (lyon)
# +2 12 RUE DU COL PAUL PAILLOLE / PL MICOULEAU (toulouse)
# -2 16 Impasse du Pré Gaudry 69007 Lyon (lyon)
# -1 Angle rue Serlin - Angle place de la comédie (lyon)
# +1 FACE 103 BIS ROUTE DE BLAGNAC (toulouse)
# -1 Quai Arloing, Côté Saône (lyon)
# -1 Face rue Massena, entrée centre commercial (lyon)
# +1 2, rue de Jemmapes - 2, avenue Jean-Claude Bonduelle (nantes)
# -1 Boulevard Charles Stoessel entrée Parc des Sport Patinoire (mulhouse)
# +1 24 BIS CHE AMOUROUX (toulouse)
# +2 217b–221 Avenue Jean Jaurès 69007 Lyon (lyon)
# +1 40 ALLEE CHARLES DE FITTE (toulouse)
# +1 101 cours Charlemagne Lyon 2 direction centre ville. Devant l'hôtel de Région (lyon)
# -1 FACE 176 AV DE CASTRES (toulouse)
# +1 Smartinska cesta 58 (ljubljana)
# -2 Savska cesta 1 (ljubljana)
# +2 AL BRÉCK - VIADUC / BOULEVARD DE LA PETRUSSE (luxembourg)
# -1 Fitzwilliam Square West (dublin)
# -1 Maximiliano Thous - Luz Casanova (valence)
# -1 GUTENBERG - SQUARE GUTENBERG (FACE N° 5)/GUTENBERGSSQUARE (TEGENOVER N° 5) (bruxelles)
# -1 Manuel Broseta i Pont - Naranjos (valence)
# +1 AVENIDA HYTASA - Aprox. C/ Romeral (seville)
# +1 DOMAINE / DOMEIN - AV DU DOMAINE (FACE 150) / DOMEINELAAN (VOOR 150) (bruxelles)
# -1 Guillem de Castro (Torres de Quart) (valence)
# -1 Francia - Menorca (valence)
# -1 Strossmayerjeva ulica 3 (maribor)
# +1 Pio XII - Menéndez PIdal (Nuevo Centro) (valence)
# -1 Aragón - Ernesto Ferrer (valence)
# -1 AVENIDA SANCHEZ PIZJUAN - Facultad de Medicina (seville)
# +1 Šmartinska cesta 28 (ljubljana)
# -1 Juan Verdeguer - Toneleros (valence)
# -1 PLAZA DE LAS MERCEDARIAS - Aprox. C/ Ibarra (seville)
# +1 Fenian Street (dublin)
# +1 - MERKELS PLAZ - RUE JEAN BAPTISTE MERKELS / Bd CHARLES MARX (luxembourg)
# +1 Avda Alberto Jiménez Becerril - Antes Calle Maimonides (seville)
# -1 Poljanska cesta 50 (ljubljana)
# +1 The Point (dublin)
# +1 Blasco Ibañez - Mestre Ripoll (valence)
# -1 Perez Galdós - Nou Moles (valence)
# -1 CALLE ARROYO - Aprox. C/ Tena (seville)
# +1 CHATELAIN/KASTELEIN - RUE DE L'AQUEDUC /AQUADUCTSTRAAT 115-117-119 (bruxelles)
# +1 Gaspar Aguilar - Músico Penella (valence)
# +1 BGL BNP PARIBAS  - RUE EDOUARD STEICHEN ( FACE N° 10 ) (luxembourg)
# +1 Talbot Street (dublin)
# +1 AVENIDA REINIDO UNIDO - Aprox. Avda de Italia (seville)
# +1 BOURSE / BEURS - RUE PAUL DEVAUX/PAUL DEVAUXSTRAAT (bruxelles)
# +1 Škrabčeva ulica 2 (ljubljana)
# +1 AVENIDA DE ROMA - Puerta de Jerez (seville)
# +1 - KOLLEISCH - RUE DE BRAGANCE (luxembourg)
# -1 AVENIDA REINA MERCEDES - Aprox. C/ Profesor García González (seville)
# +1 Aitana - Florista (valence)
# +1 CHARLY'S GARE - BOULEVARD PRINCE HENRI (luxembourg)
# +1 GARE CENTRALE 2 - PLACE DE LA GARE N°3-5 (luxembourg)
# -1 Autopista del Saler - Antonio Ferrandis (C.C. El Saler) (valence)
# -1 ALAMEDA DE HÉRCULES - Aprox. C/ Vulcano (seville)
# +2 AUBERGE DE JEUNESSE - RUE DELAUNOY/STRAAT ,67 (bruxelles)
# +1 MUSEE DU TRAM - AVENUE DE TERVUREN / TERVURENLAAN (bruxelles)
# +1 Hospital Nueva Fe (consultas externas) (valence)
# -1 Trg MDB 9 (ljubljana)
# -1 Dame Street (dublin)
# +1 Celovška 163 (ljubljana)
# +1 Guillem de Castro - San Pedro Pascual (valence)
# +1 Gedimino pr. – J. Tumo-Vaižganto g. sankryža (vilnius)
# -1 CALLE MUÑOZ LEÓN - Aprox. C/ Morera (seville)
# -1 Av. Puerto - Plaza Tribunal de les Aigües (valence)
# +1  (lund)
# -1 Regne de Valencia - Almirante Cadarso (valence)
# -1 北新町１丁目３番 1-3 Kitashin-machi (toyama)
# +1 新桜町７番 7 Shinsakura-machi (toyama)
# +1 Angle rue de Marseille (lyon)
# -1 50 M AVANT 4 RUE DES GALLOIS (toulouse)
# -1 Angle Rue de la Guillotiere (lyon)
# +1 62 BD DE SUISSE (toulouse)
# +1 16 BVD DE LA CROIX-ROUSSE (lyon)
# -1 8,rue André Tardieu (nantes)
# -1 Cours Gambette - Prolongement rue Rachais (lyon)
# -1 Allée de la Bourse - Boulevard des Nations-Unies (nantes)
# +1 ALLEE CHARLES DE FITTE / FACE JARDIN RAYMOND VI (toulouse)
# -1 Rue Colin - Angle rue Alexis Perroncel (lyon)
# -1 47 BD LASCROSSES (toulouse)
# -1  (lyon)
# -1 15 RUE PAUL BERNIES (toulouse)
# -1 55 RUE DE LA VILLETTE (lyon)
# +2 12 PLACE LAGANNE (toulouse)
# -1 Rue Domer/angle rue Chevreul (lyon)
# +1 Rue du Professeur Beauvisage (lyon)
# +1 Face ancien Palais de Justice (lyon)
# -1 Rue de la Martinière (lyon)
# -1 REPUBLIQUE COUTELLERIE - RUE DE LA REPUBLIQUE ANGLE RUE DE LA COUTELLERIE (marseille)
# +1 Bd du 11 novembre angle av. Claude Bernard (lyon)
# +1  (lyon)
# +1 16 RUE DES REMPARTS D'AINAY (lyon)
# -1  (lyon)
# +1 Avenue du Cdt Lherminier/Angle rue F. de Pressensé (lyon)
# -6 RUE DE LA CHAUMIERE / 50 M APRES RD-PT DU CAPITAINE DREYFUS (toulouse)
# -1 Angle rue Chinard/rue St Cyr (lyon)
# +2 Côté rue des Marroniers (lyon)
# -1  (lyon)
# +1 Angle rue des Aqueducs (lyon)
# +1 15, rue de Verdun (nantes)
# -1 FACE 79 AV ALBERT BEDOUCE (toulouse)
# -1 20, quai des Antilles (nantes)
# -1 Rue de la République (lyon)
# +1 Bd Maignan Larivière (amiens)
# -1 Angle rue Villon (lyon)
# +1 FACE 49 AV D' ITALIE (toulouse)
# -1 Avenue du Général Foy (amiens)
# -1 Rue Tissot / angle rue de Bourgogne (lyon)
# -1 7 RUE DES SALENQUES (toulouse)
# +1 Angle République / rue de la Barre (lyon)
# -1 7 PLACE JULES GRANDCLEMENT (VILLEURBANNE) (lyon)
# -1 65 RUE MAZENOD (lyon)
# -1 Entre la cathédrale et le funiculaire (lyon)
# +1 126 RUE DU 8 MAI 1945 (VILLEURBANNE) (lyon)
# +1 64 BVD EUGENE REGUILLON (VILLEURBANNE) (lyon)
# +1 17T BD LASCROSSES (toulouse)
# -1 Cours Emile Zola/Angle cours de la République (lyon)
# -1 96 RUE CHEVREUL (lyon)
# -1 A côté du stand de fleurs (lyon)
# +5  (lyon)
# -1 3 RUE DE L'UNIVERSITE (toulouse)
# -1 43 BVD DU 11 NOVEMBRE 1918 (VILLEURBANNE) (lyon)
# -1 CANEBIERE SAINT FERREOL - ANGLE CANEBIERE SAINT FERREOL (marseille)
# -1 Rue Professeur Bouvier/Angle rue du 8 mai 1945 (lyon)
# +1 BD RICHARD WAGNER / ANGLE RUE ANTONIO VIVALDI (toulouse)
# -1 66 TER AV ETIENNE BILLIERES (toulouse)
# -2 bd ferdinands de lesseps angle rue amedee dormoy (rouen)
# -1 2 PLACE SAINT-SERNIN / ANGLE 2 RUE DES 3 RENARDS (toulouse)
# +1  (lyon)
# +1 FACE AU 5 RUE RENE LEDUC (toulouse)
# +1 Place Gabriel Péri (lyon)
# -1 26 RUE DE PERIGORD (toulouse)
# +1 AZALEES / AZALEA -   AVENUE PAUL DESCHANEL/LAAN FACE/TEGENOVER N°  6-8 (bruxelles)
# +1 GUTENBERG - SQUARE GUTENBERG (FACE N° 5)/GUTENBERGSSQUARE (TEGENOVER N° 5) (bruxelles)
# -1 LA CHASSE/JACHT - AVENUE DES CASERNES/ KAZERNENLAAN 4 - 6 (bruxelles)
# +2 PARVIS DE ST GILLES/ST-GILLISVOORPLEIN - CHAUSSEE DE WATERLOO/ WATERLOOSESTEENWEG 65-69 (bruxelles)
# -1 Harcourt Terrace (dublin)
# -1 Bolton Street (dublin)
# +1 Grangegorman Lower (South) (dublin)
# -1 Leinster Street South (dublin)
# -1 Fontanars dels Aforins - Vall d'Uixó (valence)
# -1 Savska cesta 1 (ljubljana)
# -1 CALLE LUIS MONTOTO - Aprox. C/ Maese Farfán (seville)
# +1 Campoamor - Músico Ginés (valence)
# +1 Doctor Vicente Zaragozá - Ramón Asensio (valence)
# +1 Uruguay - Carteros (valence)
# -1 Pogačarjev trg 3 (ljubljana)
# +1 Manuel Broseta i Pont - Naranjos (valence)
# +1 AVENIDA TORNEO - Aprox. C/ Juan de Acre (seville)
# +1 Guillem de Castro (Torres de Quart) (valence)
# -1 Av Puerto 19 (Telefónica) (valence)
# +1 Pobreška cesta 18 (maribor)
# +3 Pavía (Instituto Isabel de Villena) (valence)
# +1 North Circular Road (O'Connell's) (dublin)
# +1 CALLE THARSIS - Aprox. C/ Aorno (seville)
# -1 PLAZA DE CUBA - Aprox. Puente de San Telmo (seville)
# +1 Luis García Berlanga Martí - Menorca (valence)
# -1 PLAZA DE LAS MERCEDARIAS - Aprox. C/ Ibarra (seville)
# -1 Gunduličeva ulica (ljubljana)
# +1 Manuel de Falla - Hernández Lázaro (valence)
# -1 Xátiva - Bailén (Estación del Norte) (valence)
# +1 City Quay (dublin)
# +1 Rue St.Mathieu/ prés de l'arrêt Pafendall (luxembourg)
# +1 Gregorio Gea - Padre Ferris (valence)
# -1 CALLE DE MADRESELVA - Aprox. Ronda de Pio XII (seville)
# +1 AVENIDA ALCALDE JUAN FERNÁNDEZ - Aprox. C/ Profesor Buenaventura Pinillos (seville)
# -1 Dunajska cesta 50 (ljubljana)
# -1 Av. Puerto - José Aguilar (valence)
# +1 GASTON DIDERICH - AVENUE GASTON DIDERICH (luxembourg)
# +1 Nicasio Benlloch - Amics dels Corpus (valence)
# +1 Gerbičeva ulica 61 (ljubljana)
# -1 Blasco Ibañez - Jaime Roig (valence)
# +1 AVENIDA DE ROMA - Puerta de Jerez (seville)
# +1 Fray Juanípero Serra - Torrente (valence)
# -1 LABOURS - RUE DES LABOURS / BLD J.F.KENNEDY (luxembourg)
# -1 Rubén Darío - Plaza Fray Luis Colomer (valence)
# +1 AVENIDA KANSAS CITY - Aprox. Hotel Occidental (seville)
# -1 Blasco Ibañez - Poeta Durán Tortajada (valence)
# -1 Salvador Ferrandis Luna - Juan Bautista Vives (valence)
# -1 CALLE RAFAEL SALGADO - Aprox. C/ Castillo Alcala de Guadaira (seville)
# +1 CALLE PINO MONTANO - Aprox. C/ Estafeta (seville)
# -1 Vicent Vidal - Pintor Maella (valence)
# +1 AVENIDA REINA MERCEDES - Aprox. Glorieta Alcalde de Parias Merry (seville)
# +1 Manuel Candela - Rodriguez de Cepeda (valence)
# -2 STROOSSBUERGER PLAZ - PLACE DE STRASBOURG ( FACE N° 41 ) (luxembourg)
# -1 Ulica Ambrožiča Novljana (ljubljana)
# -1 AVENIDA DE ANDALUCIA - Aprox. Cochera de TUSSAM (seville)
# +1 Fernando el Católico - Cuenca (valence)
# -1  (lund)
# +1 Plaza de los Fueros - Conde Trenor (valence)
# -1 CALLE VIRGEN DE LUJÁN - Aprox. Glorieta las Cigarreras (seville)
# -1 富山市明輪町1内 Station Plaza South (toyama)
# -1 MAZARGUES - ROND POINT DE MAZARGUES (OBELISQUE) (marseille)
# -1 Devant le n°41 rue de la Quarantaine (lyon)
# -1 Angle rue Vendôme (lyon)
# +1 Angle rue de Marseille (lyon)
# -1 Avenue Fontaine Argent angle rue Beauregard (besancon)
# -1 Face Entrée du Parc de la Tête d'Or** (lyon)
# -1 50 RUE DU GENERAL COMPANS (toulouse)
# -1 49 AV. GENERAL LECLERC (VILLEURBANNE) (lyon)
# -1 Avenue Jean Jaurès - Angle rue de la Guillotière (lyon)
# -1 62 BD DE SUISSE (toulouse)
# +1 3, boulevard Léon Bureau (nantes)
# -1 69 RUE AUDIBERT ET LAVIROTTE (lyon)
# +1 5 PL ROBERT SCHUMAN (toulouse)
# +1 Place de la Paix - En face de La Poste (lyon)
# -1 54 COURS ALBERT THOMAS (lyon)
# -1 Angle rue Tupin / rue Herriot (lyon)
# -1 19T ALL DE BRIENNE (toulouse)
# +1 SAINTE LULLI - 17 RUE SAINTE (marseille)
# +1 1, boulevard des Martyrs Nantais de la Résistance (nantes)
# +1 Angle cours Tolstoï (lyon)
# +1 Place du Commerce - Cours Franklin Roosevelt (nantes)
# -1 ENDOUME CORDERIE - 41 RUE D'ENDOUME (marseille)
# +1 Rue Domer/angle rue Chevreul (lyon)
# -3 3, place de la République (nantes)
# -1 16 RUE DES REMPARTS D'AINAY (lyon)
# -2 Angle rue de la Madeleine (lyon)
# +1 FACE 80 RUE SAINT ROCH / ANGLE AC DU 14EME REGIMENT D'INFANTERIE (toulouse)
# +1  (lyon)
# +1 Angle rue Vendôme (lyon)
# +1  (lyon)
# +1 Place Victor Basch (lyon)
# -1 CORNICHE LE PROPHETE - 327 CORNICHE J.F KENNEDY FACE A LA PLAGE DU PROPHETE EN DIRECTION DU VIEUX PORT (marseille)
# +1 12 QUAI ST AINTOINE (lyon)
# +1 3 RUE JEAN DE TOURNES (lyon)
# -1 15 PL ETIENNE ESQUIROL (toulouse)
# -1 20, quai des Antilles (nantes)
# -1 Angle rue Villon (lyon)
# +1 MAZARGUES BARRAL - ANGLE AVENUE DE MAZARGUES ET BOULEVARD BARRAL (marseille)
# +1 Angle République / rue de la Barre (lyon)
# -1 25, boulevard Victor Hugo - 28, boulevard Gustave Roch (nantes)
# +1 Angle cours Charlemagne (lyon)
# -1 6 PLACE SATHONAY (lyon)
# -1 Angle rue d'Algérie (lyon)
# -1 4 PLACE RASPAIL (lyon)
# +1 23, quai Ferdinand Favre (nantes)
# +1 44 RUE SALA (lyon)
# -1 65 RUE MAZENOD (lyon)
# -1 4 RUE DE LA CONCORDE (toulouse)
# -1 AVENUE DU PARC ANGLE BOULEVARD DE L'HAUTIL - 95000 CERGY (cergy-pontoise)
# +1 Entre la cathédrale et le funiculaire (lyon)
# +1 126 RUE DU 8 MAI 1945 (VILLEURBANNE) (lyon)
# +1 rue de la Technologie (lyon)
# +1 2 PLACE SAINT-PIERRE (toulouse)
# +1 76 BD DE LA GARE (toulouse)
# +2 Cours Emile Zola/Angle cours de la République (lyon)
# -1  (lyon)
# +1 48 BD D'ARCOLE (toulouse)
# +2  (lyon)
# +1  (lyon)
# +1 Avenue de la Martellière - SAINT-SÉBASTIEN-SUR-LOIRE (nantes)
# +1 20 M APRES 122 QUAI DE TOUNIS (toulouse)
# +1 Sur le quai devant l'entrée de la piscine (lyon)
# -2 7 RUE DU REMPART ST ETIENNE (toulouse)
# +1 16 Impasse du Pré Gaudry 69007 Lyon (lyon)
# -1 CANEBIERE SAINT FERREOL - ANGLE CANEBIERE SAINT FERREOL (marseille)
# -1 Pont de la Tortière - boulevard Eugène Orieux (nantes)
# +1 TOULON MENPENTI - ANGLE AVENUE DE TOULON ET RUE MENPENTI (marseille)
# +1 Face rue Massena, entrée centre commercial (lyon)
# -1 86 RUE DE LA CHARITE (lyon)
# -1 bd ferdinands de lesseps angle rue amedee dormoy (rouen)
# -1 Av Piaton / angle Condorcet (lyon)
# -1 Angle rue Paul Bert (lyon)
# -1 Mount Street Lower (dublin)
# -1 Glavni trg 20 (maribor)
# +1 Doctor Vicente Zaragozá - Ramón Asensio (valence)
# -1 Pearse Street (dublin)
# +1 Excise Walk (dublin)
# -1 Salamanca - Conde Altea (valence)
# -1 Pogačarjev trg 3 (ljubljana)
# +1 Cankarjeva cesta 1 (ljubljana)
# +1 Prušnikova ulica (ljubljana)
# +1 Tehnološki park (ljubljana)
# +1 Micer Mascó - Rodriguez Fornos (valence)
# -1 Av Puerto 19 (Telefónica) (valence)
# -1 Calle Fray Isidoro de Sevilla - Aprox C/ Álvarez Chanca (seville)
# +1 Pobreška cesta 18 (maribor)
# +1 GARE DE LUXEMBOURG/LUXEMBURGSTATION - RUE DE TREVES / TRIERSTRAAT (bruxelles)
# +1 Murta - Sant Eperit (valence)
# +1 Collins Barracks Museum (dublin)
# -1 Ilirska ulica 1 (ljubljana)
# -1 CALLE CUESTA DE ROSARIO - Pza de la Pescadería (seville)
# -1 John Street West (dublin)
# +1 Gunduličeva ulica (ljubljana)
# -1 Merrion Square South (dublin)
# +1 UPV Informática (valence)
# -1 ALAMEDA DE HERCULES - Aprox. C/ Amor de Dios (seville)
# -1 King Street North (dublin)
# -1 GASTON DIDERICH - AVENUE GASTON DIDERICH (luxembourg)
# +1 Armada Española - Mariano Cuber (valence)
# +1 RONDA CAPUCHINOS - Aprox. C/ Corinto (seville)
# +1 Baleares - Río Escalona (valence)
# -1 Celovška cesta 111c (ljubljana)
# +1 PLAZA DEL ZURRAQUE - Aprox. C/ Doc. Jeronimo Pou (seville)
# -1 KRAIZGRENNCHEN - SQUARE DE NEW- YORK (luxembourg)
# -1 General Elio - Llano del Real (valence)
# -1 - KOLLEISCH - RUE DE BRAGANCE (luxembourg)
# +1 CARRETERA DE CARMONA - Aprox. Avda de Llanes (seville)
# -1 CALLE VICTORIA KENT - Aprox. Avda Alcalde Manuel del Valle (seville)
# +1 Plaza América - Cirilo Amorós - Sorní (valence)
# +1 CALLE SINAÍ - Aprox. C/ Baltazar Gracián (seville)
# -2 Blasco Ibañez - Poeta Durán Tortajada (valence)
# -1 ALAMEDA DE HÉRCULES - Aprox. C/ Vulcano (seville)
# +1 Salvador Ferrandis Luna - Juan Bautista Vives (valence)
# +1 Economista Gay - Constitución (valence)
# +1 Plaza de Europa (valence)
# -1 Trg OF 12 (ljubljana)
# -1 Celovška 163 (ljubljana)
# -1 STROOSSBUERGER PLAZ - PLACE DE STRASBOURG ( FACE N° 41 ) (luxembourg)
# -1 CALLE ENRAMADILLA - Aprox. C/ Barrau (seville)
# -1 Esparraguera - Cra. Malilla (valence)
# +1 Plaza Poeta Llorente (valence)
# +2 SQUARE ANDRE - SQUARE EDOUARD ANDRE ( DEVANT N° 1 ) (luxembourg)
# +2 CALLE MUÑOZ LEÓN - Aprox. C/ Morera (seville)
# +1 Plaza de los Fueros - Conde Trenor (valence)
# +1 VAN HELLEMONT - RUE DE NEERPEDE 372-374 / NEERPEDESTRAAT 372-374 (bruxelles)
# +1 AVENIDA SOLEA - Aprox. C/ Media Granaína (seville)
# +1 新富町１丁目２番４号 1-2-4 Shintomi-cho (toyama)
# -1 3 Place de la République (mulhouse)
# -1 Angle montée de la Boucle (lyon)
# -1 68 BD JEAN BRUNHES FACE AU 53 (toulouse)
# +1 12  AV  ETIENNE  BILLIERES (toulouse)
# -1 57 RUE DU PRINTEMPS (toulouse)
# +1 39 BIS AV DE LOMBEZ (toulouse)
# +1 54 COURS ALBERT THOMAS (lyon)
# -1 Face parvis du palais des congrès (lyon)
# +1 Angle rue Tupin / rue Herriot (lyon)
# +3 SAINTE LULLI - 17 RUE SAINTE (marseille)
# -1 12 RUE DU POIDS DE L'HUILE (toulouse)
# -1 6 RUE DU REMPART VILLENEUVE (toulouse)
# -1 174–180 Avenue Jean Jaurès 69007 Lyon (lyon)
# -1 Parvis entrée parc Chanot (marseille)
# -1 8 ALL DES DEMOISELLES (toulouse)
# +1 QUAI DU PORT - 148 QUAI DU PORT (marseille)
# -3 42, boulevard Gabriel Guist'Hau (nantes)
# +1 RABATAU TEISSEIRE - ANGLE BOULEVARD RABATAU ET FACE AU 68 RUE RAYMOND TEISSEIRE (marseille)
# +6 2 RUE DES MOUETTES / ANGLE ALL HENRI SELLIER (toulouse)
# -2 12 COURS CHARLEMAGNE (lyon)
# -1 14 PL SAINT-ETIENNE (toulouse)
# -1 FACE 25 RUE DE L AUDE (toulouse)
# +2 161/163 AV DE NEGRENEYS SUR ILOT CENTRAL (toulouse)
# +1 PL DU DR JOSEPH BAYLAC ANGLE AV DES ARENES ROMAINES (toulouse)
# -1 118 RUE MONCEY (lyon)
# +1 GAMBETTA LAFAYETTE - 6 ALLEES LEON GAMBETTA (marseille)
# -1 18 ALLEE FREDERIC MISTRAL (toulouse)
# +1 Angle Bld Y. Farge / rue Commandant Ayasse (lyon)
# +1 1 RUE DE L ESQUILE (toulouse)
# +1  (lyon)
# -1 ANGLE RUE BILLON / RUE F. DE PRESSENSE (lyon)
# +1 95 AV. DE L'EUROPE (lyon)
# -1 6 RUE JEAN RENOIR (lyon)
# +1 AVENUE PASTEUR (rouen)
# +1 CORNICHE LE PROPHETE - 327 CORNICHE J.F KENNEDY FACE A LA PLAGE DU PROPHETE EN DIRECTION DU VIEUX PORT (marseille)
# -1 12 RUE DU LANGUEDOC (toulouse)
# +1 Face station tram Ste Blandine (lyon)
# -1 Rue de la Platière - Angle quai de la Pêcherie (lyon)
# -2 Place Foch (nantes)
# -1 Rue Garibaldi - Angle avenue Berthelot (lyon)
# -1 METRO GRAMONT / ANGLE RUE SAINT JEAN (toulouse)
# -1 CORNICHE ENDOUME - 126 CORNICHE J.F. KENNEDY (marseille)
# +1 Avenue Lacassagne (lyon)
# +1 Angle rue Garibaldi (lyon)
# +1 Côté est de la place (lyon)
# +1 Cours Emile Zola/Angle cours de la République (lyon)
# +1  (lyon)
# -2 20 M APRES 122 QUAI DE TOUNIS (toulouse)
# -1 angle rue de rome rue sylvabelle (marseille)
# +1  (lyon)
# +1 Face rue Massena, entrée centre commercial (lyon)
# +1 PRADO DUVEEN - 72 AVENUE DU PRADO (marseille)
# +1 Devant le bâtiment du Klesia (lyon)
# -4 bd ferdinands de lesseps angle rue amedee dormoy (rouen)
# -1  (lyon)
# -1 PLACE BELLECOUR Côté rue Lintier (lyon)
# +1 49 RUE SGT BERTHET (lyon)
# +1 CALLE PAEZ DE RIVERA - Aprox. Paseo de la Palmera (seville)
# +1 Mount Street Lower (dublin)
# +1 Glavni trg 20 (maribor)
# +1 Masarykova cesta 14 (ljubljana)
# -2 Salamanca - Conde Altea (valence)
# +1 Ulica slovenske osamosvojitve 5 (maribor)
# -5 Esquina rotanda Torreblanca (seville)
# +1 Rue Albert Einstein/Bd de Kockelscheuer (luxembourg)
# +1 PLAZA NUEVA - Aprox. C/ Tetuan (seville)
# +2 LOI/WET - RUE D'ARLON/STRAAT 120 (bruxelles)
# +2 Av Puerto 19 (Telefónica) (valence)
# +2 Pobreška cesta 18 (maribor)
# -1 GARE DE LUXEMBOURG/LUXEMBURGSTATION - RUE DE TREVES / TRIERSTRAAT (bruxelles)
# +1 Custom House (dublin)
# -2 CALLE CORRAL DEL AGUA - Aprox. Camino de los toros (seville)
# +1 Strossmayerjeva ulica 3 (maribor)
# -1 Aragón - Ernesto Ferrer (valence)
# +1 Luís Peixó 20 (valence)
# +1 Doctor Vicente Zaragozá - Emilio Baró (valence)
# +4 Alberique, 18 (Abastos) (valence)
# +1 Peris y Valero - Cuba (valence)
# +1 Campanar - Nicasio Benlloch (valence)
# +1 Gunduličeva ulica (ljubljana)
# -1 Xátiva - Bailén (Estación del Norte) (valence)
# -1 Pavía - Columbretes (valence)
# -1 City Quay (dublin)
# -1 PLAZA DEL ALTOZANO - Aprox. C/ San Jorge (seville)
# +1 Gregorio Gea - Padre Ferris (valence)
# +1 Blasco Ibañez - Yecla (valence)
# +1 PAUL JANSON - CHAUSSEE DE CHARLEROI/ CHARLEROISESTEENWEG 159 (bruxelles)
# -2 ALAMEDA DE HERCULES - Aprox. C/ Amor de Dios (seville)
# +1 Ulica Moše Pijada 6 (maribor)
# +1  (luxembourg)
# +1 Economista Gay - Luis Crumiere (valence)
# +1 AVENIDA DE ANDALUCIA - Aprox. Centro Comercial Los Arcos (seville)
# -1 Železna cesta 18 (ljubljana)
# -1 AVENIDA EDUARDO DATO - Aprox. C/ Oscar Carvallo (seville)
# +1 High Street (dublin)
# +1 Upės g. (šalia VCUP) (vilnius)
# -1 AVDA DE PALMAS ALTAS - Aprox. CC LAGOH junto a pasarela peatonal (seville)
# -2 Custom House Quay (dublin)
# -1 Molesworth Street (dublin)
# +1 Kongresni trg 3 (ljubljana)
# -1 Av. Puerto - Doctor Manuel Candela (valence)
# -1 Kevin Street (dublin)
# +1 Blasco Ibañez, 28 (F. Geografía e Historia) (valence)
# +2 ËNNESCHTGAASS - RUE NOTRE DAME 37 (luxembourg)
# -1 Večna pot 70 (ljubljana)
# -1 FLAGEY - PLACE FLAGEY (FACE 11)/EUGENE FLAGEYPLEIN (TEGENOVER 11) (bruxelles)
# -1 Barcas, 11 (valence)
# -1  (lund)
# +1 Menorca - Baleares (valence)
# -1 St. Stephen's Green East (dublin)
# +1 Amadeo de Saboya (frente Ayuntamiento) (valence)
# +1 George's Lane (dublin)
# +1 Aragón - Vicente Sancho Tello (valence)
# +1 ROGIER - BOULEVARD DU JARDIN BOTANIQUE/KRUIDTUINLAAN (bruxelles)
# +1 Phibsborough Road (dublin)
# -1 LABOURS - RUE DES LABOURS / BLD J.F.KENNEDY (luxembourg)
# -1 Ljubljanska ul. 30-25 (maribor)
# +1 Portobello Harbour (dublin)
# -1 Gregorio Gea - Profesor Beltrán Báguena (valence)
# +1 James Street (dublin)
# -1 Giorgeta - Roig de Corella (valence)
# +1 Plaza de Europa (valence)
# -1 HOLLERECHER PLAZ - PLACE SAINT PIERRE ET PAUL / RUE BAUDOUIN (luxembourg)
# -1 Trg MDB 9 (ljubljana)
# -1 Veles e Vents (valence)
# +1 Manuel Candela - Rodriguez de Cepeda (valence)
# +1 Žirmūnų g. – Tuskulėnų g. žiedinė sankryža (šalia PC IKI Minskas) (vilnius)
# +1 GLACIS KAPELL - BOULEVARD DE LA FOIRE ( DEVANT N° 21 ) (luxembourg)
# -3 Av. Puerto 61-63 (valence)
# +1 Bolton Street (dublin)
# -1 GLORIETA PLUS ULTRA - Aprox. Estadio Manuel Ruiz de Lopera (seville)
# +1  (lund)
# +1 AVENIDA SOLEA - Aprox. C/ Media Granaína (seville)
# +1 Angle rue de Marseille (lyon)
# +1 2 rue Puvis de Chavannes (amiens)
# -1 68 BD JEAN BRUNHES FACE AU 53 (toulouse)
# +1 Avenue Jean Jaurès - Angle rue de la Guillotière (lyon)
# +1 29, rue de Strasbourg (nantes)
# -1 33 Boulevard Yves Farge 69007 Lyon (lyon)
# +1 Côté nord de la place, vers l'ascenseur (lyon)
# -1 76 AV. LACASSAGNE (lyon)
# -1 39 BIS AV DE LOMBEZ (toulouse)
# -1 47 BD LASCROSSES (toulouse)
# +1 33 AV HONORE SERRES (toulouse)
# -1 SAINTE LULLI - 17 RUE SAINTE (marseille)
# -1 6, quai François Mitterrand (nantes)
# -2 RUE DE LA WANNE, angle RUE KOECHLIN (mulhouse)
# -1 FACE 52 AV BOURGES MAUNOURY (toulouse)
# +1 3 PLACE DANTON (lyon)
# +1 23 RUE DE LA VIABERT (lyon)
# +1 Angle rue Anselme, face à l'IUFM (lyon)
# -1  (lyon)
# -4 42, boulevard Gabriel Guist'Hau (nantes)
# -1 1 BIS ALLEE JULES GUESDE (toulouse)
# -2 Sur le quai haut (lyon)
# -1 Grue Jaune - Face au mail des Chantiers (nantes)
# +1 18 RUE BONNEFOY (toulouse)
# -1  (lyon)
# -1 Entre rue Crillon et rue Sully (lyon)
# -1 Avenue de la Gare d'Eau face commissariat (besancon)
# +1 10 RUE PDT P. KRUGER (lyon)
# -1 34 RUE ANTOINE LUMIERE (lyon)
# -1 3 RUE DU CHAMP DE L'ORME (VILLEURBANNE) (lyon)
# +1 42 CHEMIN AMOUROUX (toulouse)
# -1 153 RUE CREQUI (lyon)
# -1 237 RUE HENRI DESBALS (toulouse)
# -1 2 BD DU MARECHAL LECLERC (toulouse)
# +1 18 ALLEE FREDERIC MISTRAL (toulouse)
# +1  (lyon)
# -1 Quai Chauveau / angle Pont Koenig (lyon)
# -1 114 RUE DES TROENES / ANGLE STADE ERNEST WALLON (toulouse)
# -1 Angle rue Chinard/rue St Cyr (lyon)
# +1 105 ROUTE DE GENAS (VILLEURBANNE) (lyon)
# +1 FACE 3 PL BILA (toulouse)
# -1 71 COURS LAFAYETTE (lyon)
# -1 1 ESP COMPANS-CAFFARELLI (toulouse)
# +1 GENERAL DE GAULLE PARADIS - PLACE GENERAL DE GAULLE FACE AU 11 RUE PARADIS (marseille)
# -1 Place du Port Communeau (nantes)
# -2 Rue de la République (lyon)
# +1 3 BD JEAN BRUNHES (toulouse)
# +4 Angle cours Charlemagne (lyon)
# +1 32 BD DE STRASBOURG (toulouse)
# +1 91 LIBERATION - 91 BOULEVARD DE LA LIBERATION (marseille)
# -1 Place Foch (nantes)
# ...
# -1 RUE LAPUJADE / ANGLE RUE DES FLANDRES (toulouse)
# -1 23 RUE DU BEARNAIS (toulouse)
# -3 Angle rue Serlin - Angle place de la comédie (lyon)
# +1 66 TER AV ETIENNE BILLIERES (toulouse)
# -1 14 PL DOMINIQUE MARTIN DUPUY (toulouse)
# +1 61 RUE DU DAUPHINE (lyon)
# -1 Place Gabriel Péri (lyon)
# -1 Allée A. Lignon (lyon)
# -1 64 AV. JEAN JAURES (lyon)
# +1 4 BVD EUGENE DERUELLE (lyon)
# +1 Plaza de Italia (Aprox. C/ de Joaquín Costa) (santander)
# +1 PLAZA SAN AGUSTIN - Aprox. C/ Concepción (seville)
# +1 Grantham Street (dublin)
# -1 CALLE DE MANUEL VILLALOBOS - Aprox. C/ Sor Francisca Dorotea (seville)
# +1 ULB - AV BUYL CROISEMENT AV DE L'UNIVERSITE (DEVANT L'ULB) (bruxelles)
# +1 DIAMANT/DIAMANT - RUE COLONEL BOURG EN FACE 3 (bruxelles)
# -2 San José de Calasanz - Salas Quiroga (valence)
# -2 JOSEPH II/JOZEF II - RUE JOSEPH II/JOZEF II-STRAAT (bruxelles)
# -1 Partizanska cesta 46-48 (maribor)
# +1 KNUEDLER - PLACE GUILLAUME (luxembourg)
# +1 Strossmayerjeva ulica 3 (maribor)
# +2 Grudnovo nabrežje 3 (ljubljana)
# -1 AVENIDA RAMÓN Y CAJAL - Aprox. Avda de la Ciudad Jardín (seville)
# -1 Hanover Quay (dublin)
# -1 Prule 8 (ljubljana)
# -1 PRADO DE SAN SEBASTIAN - Estación de autobuses (seville)
# +1 CONGRES - RUE ROYALE/KONINGSSTRAAT 144-146-148 (bruxelles)
# -1 AVENIDA SANCHEZ PIZJUAN - Facultad de Medicina (seville)
# -1 Slovenska cesta 55c (ljubljana)
# -1 Ilirska ulica 1 (ljubljana)
# -1 Alfahuir - Peñiscola (valence)
# +1 Koroška cesta 74 (maribor)
# -1 AUMALE - RUE D'AUMALE / AUMALESTRAAT 339-341 (bruxelles)
# -1 North Circular Road (dublin)
# +1 ROCADE-RUE DU LABORATOIRE ( DEVANT VDL ) (luxembourg)
# +1 Kongresni trg 3 (ljubljana)
# -2 BOURSE / BEURS - RUE PAUL DEVAUX/PAUL DEVAUXSTRAAT (bruxelles)
# +1 Blasco Ibañez - Aragón (valence)
# +1 PORTE DE NAMUR/NAAMSEPOORT - BOULEVARD DE WATERLOO 2 (bruxelles)
# +1 Germanías - Ruzafa (valence)
# -1 BTC City/Dvorana A (ljubljana)
# -1 Plaza de Tetuán (valence)
# +2 Škrabčeva ulica 2 (ljubljana)
# -1 Aragón - Vicente Sancho Tello (valence)
# -1 Peris y Valero - Salamanca (valence)
# -1 Hospital - Horno del Hospital (valence)
# +1 Plaza América - Cirilo Amorós - Sorní (valence)
# +2 CHARLY'S GARE - BOULEVARD PRINCE HENRI (luxembourg)
# +1 GENERAL BARON/GENERAAL BARON - AV DU PARC / PARKLAAN 51 - 55 (bruxelles)
# +1 Tržaška 123 (ljubljana)
# +1 Blasco Ibañez - Poeta Durán Tortajada (valence)
# -1 Rue de l'industrie/Rue Chemin de Fer/ Rue de Strassen (luxembourg)
# +2 LIBERTE - AV DE LA LIBERTE, 44 / VRIJHEIDSLAAN,44 (bruxelles)
# -1 Trg OF 12 (ljubljana)
# +1 - GEMENG STROOSSEN - RUE DES ROMAINS (luxembourg)
# -1 Moreras (Oceanográfico) (valence)
# +3 UM REIMERWEE - RUE DU KIEM (luxembourg)
# +1 CAMPUS LAMPERTSBIERG - RUE DE LA FAIENCERIE ( DEVANT N° 151 ) (luxembourg)
# +1 CALLE REYES CATÓLICOS - Aprox. C/ Gravina (seville)
# +1 Breg 20 (ljubljana)
# -1 Upper Sherrard Street (dublin)
# +1 Fernando el Católico - Cuenca (valence)
# -1 Poljanska cesta 20c (ljubljana)
# -1 STEPHANIE/STEFANIA - AV LOUISE/LOUIZALAAN 61A-63-65 (bruxelles)
# +1 LIEDTS - PLACE LIEDTS (FACE AU 38)/ LIEDTSPLEIN (TEGENOVER 38) (bruxelles)
# +1 Cours de la République/Angle Anatole France (lyon)
# -1 2 ALL FORAIN FRANCOIS VERDIER (toulouse)
# -1 139 AV. FELIX FAURE (lyon)
# -1 Avenue Jean Jaurès - Angle rue de la Guillotière (lyon)
# -1 Angle rue Hénon (lyon)
# +1 16 BVD DE LA CROIX-ROUSSE (lyon)
# +2 76 AV. LACASSAGNE (lyon)
# -1 26 RUE DE LA THIBAUDIERE (lyon)
# -1 5 PL ROBERT SCHUMAN (toulouse)
# -1 Angle rue Tupin / rue Herriot (lyon)
# +1 PRADO BORELY - 579 AVENUE DU PRADO (marseille)
# +1 BAILLE FRIEDLAND - BOULEVARD BAILLE ANGLE RUE DE FRIEDLAND (marseille)
# +1 Face 31, boulevard Emile Gabory (nantes)
# -1 Rue de la Gare - REZÉ (nantes)
# -1 12 PLACE LAGANNE (toulouse)
# -1  (lyon)
# -1 Angle rue Anselme, face à l'IUFM (lyon)
# -1 Rue de la Martinière (lyon)
# -1 RUE DE CUGNAUX (toulouse)
# -1 3 PLACE GAILLETON (lyon)
# -1 28 RUE DES MARCHANDS (toulouse)
# -1  (lyon)
# +1 7, rue Françoise Giroud - Boulevard Général de Gaulle (nantes)
# +1 2 BD SEBASTOPOL (toulouse)
# -1  (lyon)
# -1 Angle Henry IV (lyon)
# -1 Angle Bld Y. Farge / rue Commandant Ayasse (lyon)
# +1 45 RUE DE LA POUDRETTE (VILLEURBANNE) (lyon)
# -1 Place Charles Hernu / côté sud (lyon)
# -1 Quai Chauveau / angle Pont Koenig (lyon)
# -1 28 QUAI VICTOR AUGAGNEUR (lyon)
# -1 105 ROUTE DE GENAS (VILLEURBANNE) (lyon)
# -1 10 PLACE SAINTE ANNE (lyon)
# -1 4, place Emile Sarradin (nantes)
# +1 16 ALL PAUL SABATIER (toulouse)
# +1 15, rue de Verdun (nantes)
# +1 Angle cours Gambetta (lyon)
# -1  (lyon)
# +1 1 BD ARMAND DUPORTAL (toulouse)
# -2 Allée A. Lignon (lyon)
# +1 Rue de la République (lyon)
# -1 Angle rue Docteur Long/av. Lacassagne (lyon)
# -1 Rue Antoine Primat/Angle rue Decorps (lyon)
# +3 Angle cours Charlemagne (lyon)
# -1 Angle rue d'Algérie (lyon)
# +1  (lyon)
# -1 Intersection Rockefeller / Esquirol (lyon)
# -1 89B ALLEE CHARLES DE FITTE (toulouse)
# +1 4 RUE DE LA CONCORDE (toulouse)
# -1 17 PLACE JULES FERRY (lyon)
# +1 54 ALLEE JEAN JAURES (toulouse)
# -2 126 RUE DU 8 MAI 1945 (VILLEURBANNE) (lyon)
# +1 Angle rue Servient (lyon)
# -1  (lyon)
# -2 30, boulevard Gabriel Guist'Hau - Rue Harouys (nantes)
# -1 Bvd 11 Nov./prox. arret tram Condorcet (lyon)
# -1 Avenue Birmingham, sortie tunnel mode doux côté Saöne - 69000 Lyon (lyon)
# +1 FACE 287 RUE DES FONTAINES ANGLE AV DE CASSELARDIT (toulouse)
# -1 A côté du stand de fleurs (lyon)
# +1 27–33 Rue Alexander Fleming 69007 Lyon (lyon)
# +1 1 RUE DE SEBASTOPOL (toulouse)
# -1 CATALANS CORNICHE - 69 CORNICHE J.F. KENNEDY ANGLE RUE DES CATALANS (marseille)
# +1 sur la place Croix Luizet (lyon)
# -1 Angle rue Serlin - Angle place de la comédie (lyon)
# -1 JULIEN BARTHELEMY - 9 RUE 3 FRERES BARTHELEMY (marseille)
# -1 Rue Professeur Bouvier/Angle rue du 8 mai 1945 (lyon)
# +1 Rue Herriot - Devant Musée des Beaux Arts (lyon)
# +1 Entre rue de Bonnel et rue Rabelais (lyon)
# -2  (lyon)
# +1 2 AV ANTOINE DE ST EXUPERY (toulouse)
# -1 27 boulevard Stalingrad (nantes)
# -1 angle quai de Bondy (lyon)
# +1 Boulevard Stalingrad/angle rue Charlie Chaplin (lyon)
# -2 Angle Poulaillerie / République (lyon)
# +1 Angle rue Boileau (lyon)
# +1 103 RUE PIERRE VOYANT (VILLEURBANNE) (lyon)
# +1 Parnell Square North (dublin)
# +1 Plaza del Musico López Chavarri (valence)
# +1 CALLE PARQUE DE DOÑANA - Aprox. Calle Corral de los Olmos (seville)
# -1 Uruguay - Carteros (valence)
# +1 FENTANGE "Hiehl" - RUE DE BETTEMBOURG DEVANT N°75 (luxembourg)
# -1 MADOU - AVENUE DES ARTS/KUNSTLAAN 1-2 (bruxelles)
# -1 Cankarjeva cesta 1 (ljubljana)
# +2 Tehnološki park (ljubljana)
# -1 CALLE SANTA AMALIA  2, esquina POETA BODRIA (valence)
# -1 Parnell Street (dublin)
# -1 PARC/PARK - RUE ROYALE  (FACE N°66-68)/KONINGSSTRAAT (TEGENOVER N°66-68) (bruxelles)
# +1 LOI/WET - RUE D'ARLON/STRAAT 120 (bruxelles)
# +2 Francia - Menorca (valence)
# +1 Custom House (dublin)
# +1 Grudnovo nabrežje 3 (ljubljana)
# -1 Litijska cesta 53 (ljubljana)
# +1 HOTEL DES MONNAIES/MUNTHOTEL - BLD DE WATERLOO- WATERLOOLAAN 93/94/95/96/98 (bruxelles)
# +1 CALLE ENRAMADILLA - Aprox. C/ Balbino Marrón (seville)
# +1 Ilirska ulica 1 (ljubljana)
# +1 Gunduličeva ulica (ljubljana)
# +1 Gosposvetska cesta 4 (maribor)
# -1 Convento Carmelitas - Alboraya (valence)
# +1 AVENIDA HYTASA - Aprox. C/ Herramienta (seville)
# -1 Exchequer Street (dublin)
# +1 MENNEKENS - AVENUE BRIGADE PIRON (FACE AUX 80 - 82 - 84)/ BRIGADE PIRONLAAN (TEGENOVER 80 - 82 - 84) (bruxelles)
# +1 Gregorio Gea - Padre Ferris (valence)
# -1 Poljanska cesta 50 (ljubljana)
# +1 PLAZA DE ARMAS - Avda Torneo (estación de autobuses) (seville)
# +1 DUCHESSE DE BRABANT/HERTOGIN VAN BRABANT - RUE DE BIRMINGHAM / BIRMINGHAMSTRAAT (bruxelles)
# -2 CALLE DOCTOR LAFFON - Aprox. C/ Efeso (seville)
# +1 RONDPOINT CHURCHILL/ROTONDE CHURCHILL - AV MESSIDOR FACE 338/MESSIDORLAAN TEGENOVER 338 (bruxelles)
# +1 New Central Bank (dublin)
# +1 AVDA DE PALMAS ALTAS - Aprox. CC LAGOH junto a pasarela peatonal (seville)
# -1 BOUILLON - RUE DE BOUILLON / PARKING (luxembourg)
# +2 Kongresni trg 3 (ljubljana)
# -1 Dunajska 186 (ljubljana)
# -1 Rue Gerhard Mercator n°2/Bd de Kockelscheuer (luxembourg)
# -1 York Street West (dublin)
# -1 MARGUERITES - RUE DES MARGUERITES ( FACE N° 105 A ) (luxembourg)
# +2 Blasco Ibañez - Aragón (valence)
# -1 Blasco Ibañez - Jaime Roig (valence)
# -1 Platero Suárez - Milagrosa (valence)
# -1 CALLE RAMÓN CARANDE - Aprox. C/ San Salvador (seville)
# -1 CALLE JOSÉ MARÍA MORENO GALVÁN - Aprox. C/ Juan Antonio Cabestany (seville)
# +1 Plaza de Tetuán (valence)
# +1 Baleares - Río Escalona (valence)
# +1 Škrabčeva ulica 2 (ljubljana)
# +1 AVENIDA SAN FRANCISCO JAVIER - Aprox. C/ Camilo José Cela (seville)
# -1 Blasco Ibañez, 23 (F. Filosofía y Psicología) (valence)
# -1 General Elio - Llano del Real (valence)
# -1 LABOURS - RUE DES LABOURS / BLD J.F.KENNEDY (luxembourg)
# +1 CELTES/KELTEN - AVENUE DE TERVUEREN (FACE AU 17) / TERVURENLAAN (TEGENOVER 17) (bruxelles)
# +1 Zaloška cesta 1 (ljubljana)
# +1 Llano de la Zaidía - Doctor Olóriz (valence)
# -1 Plaza Ayuntamiento - Cotanda (valence)
# +1 GARE CENTRALE - PLACE DE LA GARE (Quai n°1) (luxembourg)
# -1 CHARLY'S STATION - RUE DE GRÜNEWALD / CHÂTEAU D'EAU À 2633 SENNINGERBERG (luxembourg)
# -1 Valle de la Ballestera - Pio Baroja (valence)
# +1 Hardwicke Street (dublin)
# -1 UM REIMERWEE - RUE DU KIEM (luxembourg)
# +1 Manuel Candela - Rodriguez de Cepeda (valence)
# +1 Dame Street (dublin)
# +1 CALLE URQUIZA - Aprox. C/ Venecia (seville)
# +1 Pio IX - Músico Cabanilles (valence)
# -1 TAMARIS - BD METTEWIE LAAN VOOR/FACE 71 (bruxelles)
# -1 CHAPELLE/KAPEL - PLACE DE LA CHAPELLE/KAPELLEPLEIN (bruxelles)
# +1 Wilton Terrace (dublin)
# -1 CALLE FRANCISCO MURILLO - Aprox. C/ Manuel Siurot (seville)
# -1 AVENIDA CARDENAL BUENO MONREAL - Aprox. Avda Ramón Carande (seville)
# -1 TEISSEIRE ROUBAUD - ANGLE RUE RAYMOND TEISSEIRE ET RUE MAGUY ROUBAUD (marseille)
# +1 Face Entrée du Parc de la Tête d'Or** (lyon)
# +1  (lyon)
# +1 139 AV. FELIX FAURE (lyon)
# +1  (lyon)
# +1 12  AV  ETIENNE  BILLIERES (toulouse)
# -1 76 AV. LACASSAGNE (lyon)
# -1 62 RUE DE LA POMME (toulouse)
# +1 32 PL ROQUELAINE (toulouse)
# -1 Pierre Corneille/cours Franklin Roosevelt (lyon)
# +2 55 RUE DE LA VILLETTE (lyon)
# +1 SAINTE LULLI - 17 RUE SAINTE (marseille)
# -1 16 PLACE CARNOT (lyon)
# -1 174–180 Avenue Jean Jaurès 69007 Lyon (lyon)
# -1 23 RUE GORGE DE LOUP (lyon)
# -2 12 PLACE LAGANNE (toulouse)
# -1 Route de Vienne - Angle avenue Berthelot (lyon)
# -1 Rue Charles NODIER Sortie du tunnel, direction Morne (besancon)
# -2 PLACE DU BUSCA / FACE ECOLE JEAN JAURES (toulouse)
# +1 FACE 100 AV YVES BRUNAUD (toulouse)
# -1 Le long des grilles, côté ouest de la porte (lyon)
# +1 Rue du Professeur Beauvisage (lyon)
# -1 Grue Jaune - Face au mail des Chantiers (nantes)
# +1 7 rue de la Cassotte (besancon)
# -1 6 RUE ANTOINE LUMIERE (lyon)
# +1 12 COURS CHARLEMAGNE (lyon)
# +1 Angle rue de la République (lyon)
# +1 Place des Maisons Neuves/Côté rue Jean Jaurès (lyon)
# +1 Rue Roger Salengro - Angle rue Vaillant (lyon)
# +1 Face au 2 rue de la Poudrette, Vaulx en Velin (lyon)
# -1 10 RUE DES LOIS (toulouse)
# -1  (lyon)
# -1 Place du 8 Septembre (besancon)
# +1 28 QUAI VICTOR AUGAGNEUR (lyon)
# +1 105 ROUTE DE GENAS (VILLEURBANNE) (lyon)
# +1 Angle rue Plessier (lyon)
# -1 47 ALLEE BRANLY (toulouse)
# -1 16 ALL PAUL SABATIER (toulouse)
# -1 REPUBLIQUE PLUMIER - RUE DE LA REPUBLIQUE ANGLE RUE PLUMIER (marseille)
# +1 3 QUAI ANDRE LASSAGNE (lyon)
# +1 15 PL ETIENNE ESQUIROL (toulouse)
# -1 20, quai des Antilles (nantes)
# -1 27 BD PIERRE ET MARIE CURIE (toulouse)
# -1 1, boulevard Gabriel Guist'Hau - Place Delorme (nantes)
# -2 30, boulevard Gabriel Guist'Hau - Rue Harouys (nantes)
# -2 76 BD DE LA GARE (toulouse)
# -1 Angle rue Garibaldi (lyon)
# +1 A côté du stand de fleurs (lyon)
# -1 Angle Cours Vitton (lyon)
# +1 Devant le lycée (lyon)
# +1 BAILLE HOPITAL CONCEPTION - BOULEVARD BAILLE FACE A L'ENTREE PRINCIPALE DE L'HOPITAL DE LA CONCEPTION (marseille)
# -1 FACE 58 RUE DUMERIL (toulouse)
# -1 COLBERT SAINTE BARBE - RUE COLBERT ANGLE RUE SAINTE BARBE (marseille)
# -1 50 GRANDE RUE SAINT-MICHEL (toulouse)
# -1 Face rue Massena, entrée centre commercial (lyon)
# -1 Boulevard des Belges - Angle rue Duquesne (lyon)
# +1 4 BD DE STRASBOURG (toulouse)
# +1 Rue de la Madeleine - Angle rue St Lazarre (lyon)
# +1 12 BD DE BONREPOS (toulouse)
# +1 RD PT ANGLE AV DES ARENES ROMAINES RUE JEAN ESPITALIER (toulouse)
# -1 Devant entrée de la fac (lyon)
# -1 61 RUE DU DAUPHINE (lyon)
# -2 Avenue Aristide Briand, en face de la mairie (lyon)
# -1 217b–221 Avenue Jean Jaurès 69007 Lyon (lyon)
# +1 Rue de l'Epargne (lyon)
# +1 Place Gabriel Péri (lyon)
# -1 4 BVD EUGENE DERUELLE (lyon)
# -1 Av Piaton / angle Condorcet (lyon)
# +1 Angle rue Paul Bert (lyon)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 for message in consumer:
#       2     station = json.loads(message.value.decode())
#       3     station_number = station["number"]
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1193, in KafkaConsumer.__next__(self)
#    1191     return self.next_v1()
#    1192 else:
# -> 1193     return self.next_v2()
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1201, in KafkaConsumer.next_v2(self)
#    1199     self._iterator = self._message_generator_v2()
#    1200 try:
# -> 1201     return next(self._iterator)
#    1202 except StopIteration:
#    1203     self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:1116, in KafkaConsumer._message_generator_v2(self)
#    1114 def _message_generator_v2(self):
#    1115     timeout_ms = 1000 * (self._consumer_timeout - time.time())
# -> 1116     record_map = self.poll(timeout_ms=timeout_ms, update_offsets=False)
#    1117     for tp, records in six.iteritems(record_map):
#    1118         # Generators are stateful, and it is possible that the tp / records
#    1119         # here may become stale during iteration -- i.e., we seek to a
#    1120         # different offset, pause consumption, or lose assignment.
#    1121         for record in records:
#    1122             # is_fetchable(tp) should handle assignment changes and offset
#    1123             # resets; for all other changes (e.g., seeks) we'll rely on the
#    1124             # outer function destroying the existing iterator/generator
#    1125             # via self._iterator = None
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:655, in KafkaConsumer.poll(self, timeout_ms, max_records, update_offsets)
#     653 remaining = timeout_ms
#     654 while True:
# --> 655     records = self._poll_once(remaining, max_records, update_offsets=update_offsets)
#     656     if records:
#     657         return records
#
# File /opt/conda/lib/python3.10/site-packages/kafka/consumer/group.py:702, in KafkaConsumer._poll_once(self, timeout_ms, max_records, update_offsets)
#     699     self._client.poll(timeout_ms=0)
#     701 timeout_ms = min(timeout_ms, self._coordinator.time_to_next_poll() * 1000)
# --> 702 self._client.poll(timeout_ms=timeout_ms)
#     703 # after the long poll, we should check whether the group needs to rebalance
#     704 # prior to returning data so that the group can stabilize faster
#     705 if self._coordinator.need_rejoin():
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:602, in KafkaClient.poll(self, timeout_ms, future)
#     599             timeout = min(timeout, self.config['retry_backoff_ms'])
#     600         timeout = max(0, timeout)  # avoid negative timeouts
# --> 602     self._poll(timeout / 1000)
#     604 # called without the lock to avoid deadlock potential
#     605 # if handlers need to acquire locks
#     606 responses.extend(self._fire_pending_completed_requests())
#
# File /opt/conda/lib/python3.10/site-packages/kafka/client_async.py:634, in KafkaClient._poll(self, timeout)
#     631 self._register_send_sockets()
#     633 start_select = time.time()
# --> 634 ready = self._selector.select(timeout)
#     635 end_select = time.time()
#     636 if self._sensors:
#
# File /opt/conda/lib/python3.10/selectors.py:469, in EpollSelector.select(self, timeout)
#     467 ready = []
#     468 try:
# --> 469     fd_event_list = self._selector.poll(timeout, max_ev)
#     470 except InterruptedError:
#     471     return ready
#
# KeyboardInterrupt:
